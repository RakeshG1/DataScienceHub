# %% [markdown]
# Certainly! Let's explore **logistic growth** and its application in time series forecasting using Python. 🌱
#
# ### What is Logistic Growth?
#
# **Logistic growth** is a type of population growth that starts off exponentially but eventually levels off due to limiting factors. It's commonly used to model various phenomena, such as population growth, tumor growth, and the concentration of reactants and products in autocatalytic reactions. The logistic growth curve follows an S-shaped pattern.
#
# Here are the key components of the logistic growth equation:
#
# - \(D(t)\): Represents the population size (or any other quantity) at time \(t\).
# - \(L\): The curve's maximum value (carrying capacity).
# - \(k\): The logistic growth rate.
# - \(t_0\): The sigmoid's midpoint (when the growth starts).
#
# The logistic growth equation is given by:
#
# \[ D(t) = \frac{L}{1 + e^{-k(t - t_0)}} \]
#
# ### Why Use Logistic Growth in Time Series Forecasting?
#
# 1. **Realistic Modeling:**
#    - Logistic growth captures the natural behavior of many real-world processes.
#    - It accounts for both rapid initial growth and eventual saturation.
#    - Unlike exponential growth, which continues indefinitely, logistic growth levels off.
#
# 2. **Applications in Forecasting:**
#    - Time series data often exhibit logistic growth patterns.
#    - Examples include adoption rates of new technologies, customer base growth, and disease spread.
#    - By fitting logistic curves to historical data, we can forecast future trends.
#
# ### Python Example: Fitting a Logistic Curve
#
# Let's create a simple Python example using synthetic data to fit a logistic growth curve. We'll use the `scikit-learn` library for linear regression.
#
# In this example:
# - We generate synthetic data following a logistic growth pattern.
# - We add noise to simulate real-world variability.
# - Using linear regression, we estimate the parameters \(k\) and \(L\).
# - Finally, we plot the observed data, the true logistic curve, and the fitted curve.
#
# Feel free to adapt this approach to your specific time series data! 📈
#
# For more details, you can refer to the following resources:
# - [Fitting a logistic curve to time series in Python](https://aetperf.github.io/2020/04/11/Fitting-a-logistic-curve-to-time-series-in-Python.html) ¹
# - [S-Curve Forecast in Python; Predict the Logistic Growth of a Starting Value Using an S-Curve](https://medium.com/@polanitzer/s-curve-forecast-in-python-predict-the-logistic-growth-of-a-starting-value-using-a-s-curve-bbfa34a11308) ²
# - [Time Series Analysis in Python – A Comprehensive Guide with Examples](https://www.machinelearningplus.com/time-series/time-series-analysis-python/) ³
#
# Source: Conversation with Bing, 16/5/2024
# (1) Fitting a logistic curve to time series in Python. https://aetperf.github.io/2020/04/11/Fitting-a-logistic-curve-to-time-series-in-Python.html.
# (2) S-Curve Forecast in Python; Predict the Logistic Growth of a ... - Medium. https://medium.com/@polanitzer/s-curve-forecast-in-python-predict-the-logistic-growth-of-a-starting-value-using-a-s-curve-bbfa34a11308.
# (3) Time Series Analysis in Python – A Comprehensive Guide with Examples. https://www.machinelearningplus.com/time-series/time-series-analysis-python/.
# (4) undefined. http://www.nlreg.com/aids.htm.
# (5) undefined. https://raw.githubusercontent.com/selva86/datasets/master/a10.csv.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Generate synthetic time series data
t = np.linspace(0, 10, 100)
L, k, t0 = 10000, 2, 5
D = L / (1 + np.exp(-k * (t - t0)))

# Add noise to simulate real-world data
np.random.seed(42)
D_noisy = D + np.random.normal(0, 500, len(t))

# Fit a linear regression to estimate k and L
X = D_noisy.reshape(-1, 1)
y = k * D_noisy * (1 - D_noisy / L)
reg = LinearRegression().fit(X, y)

# Extract estimated parameters
k_fit = reg.coef_[0]
L_fit = reg.intercept_ / k_fit

# Plot the data and fitted logistic curve
plt.figure(figsize=(8, 6))
plt.scatter(t, D_noisy, label="Observed Data", color="blue")
plt.plot(t, D, label="True Logistic Curve", color="green", linestyle="--")
plt.plot(t, L_fit / (1 + np.exp(-k_fit * (t - t0))), label="Fitted Logistic Curve", color="red")
plt.xlabel("Time")
plt.ylabel("Population Size")
plt.title("Logistic Growth Example")
plt.legend()
plt.show()

# %% [markdown]
# ## Logistic Growth Rate in Time Series Forecasting
#
# **Logistic Growth Rate:**
#
# The logistic growth rate, denoted by `r`, describes the rate of change in a population (or similar quantity) over time in a logistic growth model. This model captures scenarios where growth initially accelerates, then gradually slows down and eventually plateaus as the population approaches a limiting maximum, also known as the carrying capacity (`K`).
#
# **Why Use It in Time Series Forecasting?**
#
# The logistic growth model is particularly useful for forecasting time series data that exhibits an S-shaped curve, reflecting an initial period of rapid growth followed by a gradual slowdown and saturation. Here are some common applications:
#
# - **Population growth**: Forecasting population growth in a city or country.
# - **Product adoption**: Predicting the number of users adopting a new product over time.
# - **Disease outbreaks**: Modeling the spread of a disease as it reaches a peak and eventually plateaus.
#
# **Logistic Growth Model and Python Example:**
#
# The logistic growth model can be expressed mathematically as:
#
# ```
# dy/dt = r * y * (1 - y / K)
# ```
#
# where:
#
# - `y` is the population (or quantity) at time `t`
# - `r` is the logistic growth rate
# - `K` is the carrying capacity
#
# Here's a simple Python example using `scipy.integrate` to simulate logistic growth and calculate the growth rate:
#
# This code simulates the logistic growth model with given parameters, plots the population trajectory, and calculates the growth rate at a specific time point. You can adjust the parameters (`r` and `K`) and initial conditions (`y0`) to explore different scenarios.
#
# **Limitations:**
#
# - The logistic growth model assumes a constant carrying capacity and growth rate.
# - It may not be suitable for forecasting time series with external factors significantly influencing growth.
#
# By understanding and applying the logistic growth rate, you can gain valuable insights into S-shaped growth patterns within your time series data and create more accurate forecasts for such scenarios.

# %%
# from scipy.integrate import odeint
# import matplotlib.pyplot as plt
# import numpy as np

# # Define the logistic growth function
# def logistic_growth(y, t, r, K):
#   dydt = r * y * (1 - y / K)
#   return dydt

# # Initial conditions
# y0 = 10  # Initial population
# t = np.linspace(0, 10, 100)  # Time points

# # Parameters (adjust as needed)
# r = 0.5  # Logistic growth rate
# K = 100  # Carrying capacity

# # Solve the differential equation
# y = odeint(logistic_growth, y0, t, args=(r, K))

# # Plot the results
# plt.plot(t, y)
# plt.xlabel('Time')
# plt.ylabel('Population')
# plt.title('Logistic Growth')
# plt.show()

# # Calculate the logistic growth rate at a specific time (t=5)
# dydt_at_t5 = logistic_growth(y[np.where(t == 5)][0], 5, r, K)
# print(f"Logistic growth rate at t=5: {dydt_at_t5:.2f}")

# %% [markdown]
# Here's a simple Python example demonstrating logistic growth using the `scipy.integrate.solve_ivp` function:
#
# **Explanation:**
#
# 1. **Import Libraries:** We import `numpy` for numerical operations and `solve_ivp` from `scipy.integrate` to solve the differential equation.
# 2. **Logistic Growth Parameters:** We define the growth rate (`r`), carrying capacity (`K`), and initial population size (`initial_population`).
# 3. **Logistic Growth Function:** We define a function `logistic_growth` that represents the differential equation for logistic growth. The equation calculates the rate of change of the population (dy/dt) based on the current population (`y`), growth rate (`r`), and carrying capacity (`K`).
# 4. **Time Range and Initial Condition:** We set the time span for the simulation (`t_span`) and the initial population value (`y0`).
# 5. **Solve Differential Equation:** We use `solve_ivp` to solve the differential equation with the provided function, initial condition, and time range. This function returns a solution object containing the simulated time points (`t`) and population values (`y`).
# 6. **Extract Data:** We extract the time values (`time`) and population values (`population`) from the solution object.
# 7. **Plot the Curve:** We use `matplotlib.pyplot` to plot the population over time, along with a horizontal line representing the carrying capacity. This visualization helps visualize the S-shaped growth pattern of the logistic model.
#
# **Understanding the Code:**
#
# * The logistic growth equation models population growth where the rate of change is proportional to the current population and the difference between the current population and the carrying capacity.
# * `solve_ivp` is a numerical integration function that solves the differential equation and provides the population values at different time points.
#
# **Adapting the Example:**
#
# * Change the values of `r`, `K`, and `initial_population` to explore different logistic growth scenarios.
# * Modify the time span (`t_span`) to simulate for a longer or shorter period.
#
# This example provides a basic framework for simulating logistic growth in Python. You can extend it to analyze more complex scenarios or integrate this model into larger data analysis projects.

# %%
import numpy as np
from scipy.integrate import solve_ivp

# Define logistic growth parameters
r = 0.5  # Growth rate
K = 100  # Carrying capacity
initial_population = 10  # Initial population size

# Define the logistic growth differential equation
def logistic_growth(t, y):
    return r * y * (1 - y / K)

# Time range for simulation
t_span = (0, 10)  # Simulate for 10 time units

# Initial condition (population at time 0)
y0 = initial_population

# Solve the differential equation
solution = solve_ivp(logistic_growth, t_span, [y0])

# Extract time and population values from the solution
time = solution.t
population = solution.y[0]

# Plot the logistic growth curve
import matplotlib.pyplot as plt

plt.plot(time, population, label='Logistic Growth')
plt.xlabel('Time')
plt.ylabel('Population')
plt.title('Logistic Growth Simulation')
plt.axhline(y=K, color='red', linestyle='--', label='Carrying Capacity')
plt.legend()
plt.show()

# %% [markdown]
# Logistic growth is a type of growth model that describes how a quantity (such as population size, market share, or the spread of a virus) grows over time and approaches a maximum value known as the carrying capacity. The logistic growth curve is characterized by an initial exponential growth phase followed by a saturation phase, where growth slows down as it approaches the carrying capacity.
#
# Here's a simple Python example demonstrating logistic growth using the logistic function:
#
# In this example:
# - We define the logistic growth function, which takes time (`t`), carrying capacity (`K`), growth rate (`r`), and initial value (`P0`) as inputs.
# - We specify the parameters for the logistic growth curve: carrying capacity (`K`), growth rate (`r`), and initial value (`P0`).
# - We generate a range of time points (`t`) using NumPy's `linspace` function.
# - We calculate the logistic growth curve using the logistic growth function.
# - Finally, we plot the logistic growth curve using Matplotlib.
#
# You can adjust the parameters (`K`, `r`, `P0`) to explore different scenarios of logistic growth. This example provides a basic demonstration of logistic growth modeling in Python.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Logistic function
def logistic_growth(t, K, r, P0):
    """
    t: Time
    K: Carrying capacity (maximum value)
    r: Growth rate
    P0: Initial value at time t=0
    """
    return K / (1 + (K - P0) / P0 * np.exp(-r * t))

# Parameters
K = 1000  # Carrying capacity
r = 0.1   # Growth rate
P0 = 10   # Initial value at time t=0

# Time points
t = np.linspace(0, 50, 100)

# Calculate logistic growth
growth = logistic_growth(t, K, r, P0)

# Plot logistic growth
plt.figure(figsize=(10, 6))
plt.plot(t, growth, label='Logistic Growth')
plt.title('Logistic Growth Curve')
plt.xlabel('Time')
plt.ylabel('Population Size')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Certainly! Let's explore a simple example of logistic growth in Python. We'll model population growth using the logistic equation and plot the results.
#
# 1. **Logistic Growth Equation**:
#    The logistic equation describes population growth with respect to time. It's commonly expressed as a differential equation:
#    \[ \frac{dP}{dt} = rP\left(1 - \frac{P}{K}\right) \]
#    However, for our purposes, we'll use the recurrence relation form:
#    \[ P_{n+1} = P_n + rP_n\left(1 - \frac{P_n}{K}\right) \]
#    where:
#    - \(n\) is the cycle (number of iterations).
#    - \(P_n\) is the population after \(n\) cycles.
#    - \(r\) is the intrinsic growth rate.
#    - \(K\) is the carrying capacity (maximum sustainable population).
#
# 2. **Python Implementation**:
#    Let's set up the variables and create a Python function based on the logistic equation:
#
# 3. **Interpretation**:
#    - The graph shows population growth over discrete time intervals.
#    - Experiment with different initial populations, growth rates, and carrying capacities to observe changes in the graphs.
#
# Feel free to adjust the parameters and explore further! If you have any more questions or need additional assistance, feel free to ask. 😊
#
# Source: Conversation with Bing, 16/5/2024
# (1) Modelling Population Growth in Python - Michael. https://michaelneuper.com/posts/modelling-population-growth-in-python/.
# (2) Understanding Logistic Regression with Python: Practical Guide 1. https://emergetech.org/wp-content/uploads/2020/05/Understanding-Logistic-Regression-with-Python_-Practical-Guide-1.pdf.
# (3) S-Curve Forecast in Python; Predict the Logistic Growth of a ... - Medium. https://medium.com/@polanitzer/s-curve-forecast-in-python-predict-the-logistic-growth-of-a-starting-value-using-a-s-curve-bbfa34a11308.
# (4) Logistic Regression Example in Python: Step-by-Step Guide. https://www.justintodata.com/logistic-regression-example-in-python/.
# (5) Logistic Regression in Python – Real Python. https://realpython.com/logistic-regression-python/.
# (6) How to code logistic growth model in python? - Stack Overflow. https://stackoverflow.com/questions/58095934/how-to-code-logistic-growth-model-in-python.
# (7) python - Inflection and maximum growth rate Logistic Curve - Stack Overflow. https://stackoverflow.com/questions/60937927/inflection-and-maximum-growth-rate-logistic-curve.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

p_0 = 5  # initial population
r = 0.1  # intrinsic growth rate
K = 500  # carrying capacity
n = 100  # number of cycles

def p_n():
    populations = [p_0]
    for i in range(n):
        p_n = populations[i]
        p_n1 = p_n + r * p_n * (1 - p_n / K)
        populations.append(p_n1)
    return populations

def plot_p_n():
    x = list(range(n + 1))
    y = p_n()
    plt.figure()
    sns.set_style("dark")
    plt.plot(x, y, 'o')
    plt.xlabel('n')
    plt.ylabel('Pn')
    plt.title('Population vs Time (Logistic Growth)')
    plt.grid(True)
    plt.show()

plot_p_n()
