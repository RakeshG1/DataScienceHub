# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **``Normal Distribution``**:
# - Bell-shaped and symmetric, centered around the mean, with most values falling close to the mean. ``Used for data that clusters around a central value``.
#
# **``Exponential Distribution``**:
# - Right-skewed, models time until an event occurs, ``probability decreases exponentially``. Used for modeling time between events.
#
# **``Uniform Distribution``**:
# - ``Flat and constant probability, all values within the range are equally likely``. Used for generating random numbers with no preference for any subset of the range.

# %%
samples_normal = np.random.normal(loc=0, scale=1, size=1000)
samples_exponential = np.random.exponential(scale=1, size=1000)
samples_uniform = np.random.uniform(low=0, high=1, size=1000)

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.hist(samples_normal, bins=30, density=True, alpha=0.6, color='g')
plt.title('Normal Distribution')

plt.subplot(1, 3, 2)
plt.hist(samples_exponential, bins=30, density=True, alpha=0.6, color='b')
plt.title('Exponential Distribution')

plt.subplot(1, 3, 3)
plt.hist(samples_uniform, bins=30, density=True, alpha=0.6, color='r')
plt.title('Uniform Distribution')

plt.tight_layout()
plt.show()

# %%
# # Set random seed for reproducibility
# np.random.seed(42)

# # Number of samples for each class
# n_samples = 100

# # Generate features for Class 1 (non-normal distribution)
# class1 = pd.DataFrame({
#     'feature1': np.random.exponential(scale=2, size=n_samples),
#     'feature2': np.random.uniform(low=0, high=10, size=n_samples),
#     'class': 'class1'
# })

# # Generate features for Class 2 (non-normal distribution)
# class2 = pd.DataFrame({
#     'feature1': np.random.exponential(scale=5, size=n_samples),
#     'feature2': np.random.uniform(low=10, high=20, size=n_samples),
#     'class': 'class2'
# })

# # Combine the data into a single DataFrame
# df = pd.concat([class1, class2], ignore_index=True)

# # Display the first few rows of the dataset
# print(df.head())

# # Visualize the dataset
# plt.figure(figsize=(10, 6))
# for class_label, color in zip(['class1', 'class2'], ['blue', 'green']):
#     subset = df[df['class'] == class_label]
#     plt.scatter(subset['feature1'], subset['feature2'], c=color, label=class_label)
# plt.xlabel('Feature 1')
# plt.ylabel('Feature 2')
# plt.legend()
# plt.title('Non-Normal Distribution Data Visualization')
# plt.grid(True)
# plt.show()

# %% [markdown]
# - **Exponential Growth**
#
# ![image.png](attachment:image.png)

# %%
# Define parameters
a = 10  # Initial value
r = 0.2  # Growth rate (20%)
t_max = 20  # Maximum time steps

# Generate data points
t = range(-10, t_max + 1)  # Time steps from 0 to t_max
values = [a * (1 + r)**tt for tt in t]

# Create the plot
plt.plot(t, values, label='a(1+r)^t')
plt.xlabel('Time (t)')
plt.ylabel('Value')
plt.title('Exponential Growth (a=10, r=0.2)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# - **Exponential Decay**
#
# ![image.png](attachment:image.png)

# %%
# Define parameters (notice decay rate definition)
a = 100  # Initial value
r = 0.3  # Decay rate (30% decrease per step)
t_max = 20  # Maximum time steps

# Generate data points
t = range(10, t_max + 1)  # Time steps from 0 to t_max
values = [a * (1 - r)**tt for tt in t]

# Create the plot
plt.plot(t, values, label='a(1-r)^t')
plt.xlabel('Time (t)')
plt.ylabel('Value')
plt.title('Exponential Decay (a=100, r=0.3)')
plt.legend()
plt.grid(True)
plt.show()
