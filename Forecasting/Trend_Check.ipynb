# %% [markdown]
# #### `Import Libraries`

# %%
import numpy as np 
import pandas as pd
import warnings
import datetime
import pymannkendall as mk
import matplotlib.pyplot as plt 
from scipy.stats import kruskal
from matplotlib import style
from IPython.core.display import display, HTML

warnings.filterwarnings("ignore")
# Out:
# /tmp/ipykernel_53203/1541404896.py:9: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython.display
#   from IPython.core.display import display, HTML

# %%
# !pip install pymannkendall

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# - `About : scipy.stats.kruskal`
# > **Reference Link** : `https://pypi.org/project/pymannkendall/`

# %% [markdown]
# #### `Sample Data`

# %% [markdown]
# > `Usecase 1`

# %%
##### Sample Data 
data = pd.Series([1,3,6,2,5,12,14,6,5,3,2,1,
                  1,3,6,2,5,12,14,6,5,3,2,1])
print("Length of data : ", len(data))
print(data.tolist())

##### Plotting
# plt.style.use("seaborn-paper")
fig, axes = plt.subplots(1, 1, figsize=(8, 4), dpi=100)
data.plot(ax=axes, linestyle="-", linewidth=1.3, color="purple", label="Value")
plt.legend()
plt.show()
# Out:
# Length of data :  24
# [1, 3, 6, 2, 5, 12, 14, 6, 5, 3, 2, 1, 1, 3, 6, 2, 5, 12, 14, 6, 5, 3, 2, 1]

# %%
mk.original_test(data)
# Out:
# Mann_Kendall_Test(trend='no trend', h=np.False_, p=np.float64(0.8208751065576219), z=np.float64(-0.2264195724419824), Tau=np.float64(-0.036231884057971016), s=np.float64(-10.0), var_s=np.float64(1580.0), slope=np.float64(0.0), intercept=np.float64(4.0))

# %% [markdown]
# > `Usecase 2`

# %%
##### Sample Data 
data = pd.Series([1,3,6,8,9,10,12,13,14,15,17,19,21,23])
print("Length of data : ", len(data))
print(data.tolist())

##### Plotting
# plt.style.use("seaborn-paper")
fig, axes = plt.subplots(1, 1, figsize=(8, 4), dpi=100)
data.plot(ax=axes, linestyle="-", linewidth=1.3, color="purple", label="Value")
plt.legend()
plt.show()
# Out:
# Length of data :  14
# [1, 3, 6, 8, 9, 10, 12, 13, 14, 15, 17, 19, 21, 23]

# %%
mk.original_test(data)
# Out:
# Mann_Kendall_Test(trend='increasing', h=np.True_, p=np.float64(8.348462070539853e-07), z=np.float64(4.9270401130622306), Tau=np.float64(1.0), s=np.float64(91.0), var_s=333.6666666666667, slope=np.float64(1.5454545454545454), intercept=np.float64(2.454545454545455))

# %% [markdown]
# > `Usecase 3`

# %%
##### Sample Data 
data = pd.Series([23,21,21,19,17,15,13,11,11,8,6,5,3,2])
print("Length of data : ", len(data))
print(data.tolist())

##### Plotting
# plt.style.use("seaborn-paper")
fig, axes = plt.subplots(1, 1, figsize=(8, 4), dpi=100)
data.plot(ax=axes, linestyle="-", linewidth=1.3, color="purple", label="Value")
plt.legend()
plt.show()
# Out:
# Length of data :  14
# [23, 21, 21, 19, 17, 15, 13, 11, 11, 8, 6, 5, 3, 2]

# %%
mk.original_test(data)
# Out:
# Mann_Kendall_Test(trend='decreasing', h=np.True_, p=np.float64(1.3513173855450589e-06), z=np.float64(-4.832053778528645), Tau=np.float64(-0.978021978021978), s=np.float64(-89.0), var_s=np.float64(331.6666666666667), slope=np.float64(-1.6666666666666667), intercept=np.float64(22.833333333333336))
